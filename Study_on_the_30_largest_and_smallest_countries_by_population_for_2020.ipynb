# %%
import pandas as pd

file_path = 'Total_Population.csv'
data = pd.read_csv(file_path, skiprows=4)

data.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
import matplotlib.pyplot as plt

data_2020 = data[['Country Name', '2020']].dropna()

data_2020_sorted_largest = data_2020.sort_values(by='2020', ascending=False).head(30)

data_2020_sorted_largest



plt.figure(figsize=(12, 8))
plt.barh(data_2020_sorted_largest['Country Name'], data_2020_sorted_largest['2020'], color='green')
plt.xlabel('Population in 2020')
plt.ylabel('Country')
plt.title('Top 30 Countries by Population in 2020')
plt.gca().invert_yaxis()
plt.show()

# %%
import matplotlib.pyplot as plt

data_2020 = data[['Country Name', '2020']].dropna()

data_2020_sorted_smallest = data_2020.sort_values(by='2020', ascending=True).head(30)

data_2020_sorted_smallest
# Out:
#                        Country Name      2020
# 245                          Tuvalu   11069.0
# 179                           Nauru   12315.0
# 188                           Palau   17972.0
# 255          British Virgin Islands   30910.0
# 147        St. Martin (French part)   32553.0
# 84                        Gibraltar   32709.0
# 212                      San Marino   34007.0
# 149                          Monaco   36922.0
# 137                   Liechtenstein   38756.0
# 225       Sint Maarten (Dutch part)   40350.0
# 155                Marshall Islands   43413.0
# 228        Turks and Caicos Islands   44276.0
# 11                   American Samoa   46189.0
# 125             St. Kitts and Nevis   47642.0
# 164        Northern Mariana Islands   49587.0
# 78                    Faroe Islands   52415.0
# 91                        Greenland   56367.0
# 27                          Bermuda   63893.0
# 52                   Cayman Islands   67311.0
# ...

# %%
plt.figure(figsize=(12, 8))
plt.barh(data_2020_sorted_smallest['Country Name'], data_2020_sorted_smallest['2020'], color='red')
plt.xlabel('Population in 2020')
plt.ylabel('Country')
plt.title('Smallest 30 Countries by Population in 2020')
plt.gca().invert_yaxis()
plt.show()
